# %%
from obspy.core import Stream, read, UTCDateTime
import numpy as np
import matplotlib.pyplot as plt
import os 
import os.path
import pandas as pd
from mudpy import forward

# %%
def listdir_nohidden(path):
    for f in os.listdir(path):
        if not f.startswith('.'):
            yield f

# %%
path = '/Users/sydneydybing/StrainProject/2024/taiwan_strain_data/'

stas = pd.read_csv(path + 'station_data.csv')
stas
# Out:
#      Sta      Lat       Lon  Depth(m)
# 0   BCWB  24.2184  121.6891      -192
# 1   TRKB  24.1614  121.6127      -192
# 2   NTTB  24.1728  121.5259      -175
# 3   SJNB  24.1073  121.6006      -193
# 4   HGSB  23.4903  121.4237      -266
# 5   CHMB  23.4868  121.4703      -191
# 6   SSNB  23.4423  121.3981      -185
# 7   ZANB  23.3947  121.4585      -218
# 8   FBRB  23.1406  121.2796      -200
# 9   SSTB  23.1340  121.3782      -199
# 10  DONB  22.9920  121.3124      -181

# %%
# Make list of events 

dirs_list = sorted((f for f in os.listdir(path) if not f.startswith('.')), key = str.lower)
events = dirs_list[:3]
origin_times = ['2009-10-03T17:36:06.120', '2013-10-31T12:02:08.720', '2018-02-04T13:56:41.950'] # Got from USGS website
lats = [23.630, 23.590, 24.157]
lons = [121.452, 121.437, 121.708]
depths = [28.0, 10.0, 12.0]

events = np.column_stack((np.array(events), np.array(origin_times), np.array(lats), np.array(lons), np.array(depths)))

events = pd.DataFrame(events, columns = ['evt_id', 'origin_time', 'lat', 'lon', 'depth'])
events.to_csv(path + 'events_csv.csv', index = False)

# %%
events['evt_id'][1]
# Out:
# '2013-10-31_M6.3'

# %%
for i in range(len(events)):
    
    evt_id = events['evt_id'][i]
    origin_time = UTCDateTime(events['origin_time'][i])
    print(origin_time)

    for idx in range(len(stas)):

        sta = stas['Sta'][idx]
        print(sta)
        
        try: 
            ev = read(path + evt_id + '/' + sta + '.EV.sac')
            
        except:
            continue

        # ev.plot()

        starttime = origin_time - 30
        endtime = origin_time + 180
        
        ev.trim(starttime, endtime)

        # ev.plot()

        # High-pass filter
        corner_period = 1000 # seconds
        corner_freq = 1/corner_period

        filter_ev = ev.copy()

        filter_ev[0].data = forward.highpass(ev[0].data, fcorner = corner_freq, fsample = ev[0].stats.sampling_rate, order = 4)

        # Detrend
        filter_ev[0].data = filter_ev[0].data - np.mean(filter_ev[0].data[0:10])

#         RMS_strain = np.sqrt(((filterS1[0].data)**2 + (filterS2[0].data)**2 + (filterS3[0].data)**2 + (filterS4[0].data)**2)/4)         

        times = filter_ev[0].times()

        # plt.title(sta)
        # plt.plot(times, ev[0].data, label = 'EV')
        # plt.plot(times, filter_ev[0].data, label = 'Filter EV')
        # # plt.plot(times, RMS_strain, label = 'RMS')
        # # plt.xlim(1000, 1150)
        # # plt.ylim(0, max(RMS_strain[1000*20:1150*20])*1.1)
        # # plt.ylim(min(S1[0].data[1000*20:1150*20])*0.9, max(S1[0].data[1000*20:1150*20])*1.1)
        # plt.legend()
        # plt.show()

#         RMS_st = filterS1.copy()
#         RMS_st[0].stats.channel = 'RMS'
#         RMS_st[0].data = RMS_strain

#         RMS_st[0].plot()
        print(filter_ev[0].stats)
    
        if sta == 'HGSB':
            filter_ev[0].stats.station = 'HGSB'
        
        print(filter_ev[0].stats)

        # Create folder for the event
        eq_sta_save_dir = path + 'filtered_EV/' + evt_id + '/'
        # print(eq_sta_save_dir)
        if os.path.isdir(eq_sta_save_dir):
            pass
        else:
            os.makedirs(eq_sta_save_dir)

        filter_ev.write(eq_sta_save_dir + sta + '.mseed', format = 'MSEED')
# Out:
# 2009-10-03T17:36:06.120000Z
# BCWB
# TRKB
# NTTB
#          network: TW
#          station: SSNB
#         location:
#          channel: EV
#        starttime: 2009-10-03T17:35:36.119542Z
#          endtime: 2009-10-03T17:39:06.119542Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2009, 10, 3, 17, 39, 6, 119542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2009, 10, 3, 17, 35, 36, 119542))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2009, 'nzjday': 276, 'nzhour': 0, 'nzmin': 0, 'nzsec': 38, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8637647, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: SSNB
#         location:
#          channel: EV
#        starttime: 2009-10-03T17:35:36.119542Z
#          endtime: 2009-10-03T17:39:06.119542Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2009, 10, 3, 17, 39, 6, 119542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2009, 10, 3, 17, 35, 36, 119542))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2009, 'nzjday': 276, 'nzhour': 0, 'nzmin': 0, 'nzsec': 38, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8637647, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# SJNB
# HGSB
#          network: TW
#          station: SSNB
#         location:
#          channel: EV
#        starttime: 2009-10-03T17:35:36.119542Z
#          endtime: 2009-10-03T17:39:06.119542Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2009, 10, 3, 17, 39, 6, 119542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2009, 10, 3, 17, 35, 36, 119542))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2009, 'nzjday': 276, 'nzhour': 0, 'nzmin': 0, 'nzsec': 50, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8637706, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: HGSB
#         location:
#          channel: EV
#        starttime: 2009-10-03T17:35:36.119542Z
#          endtime: 2009-10-03T17:39:06.119542Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2009, 10, 3, 17, 39, 6, 119542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2009, 10, 3, 17, 35, 36, 119542))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2009, 'nzjday': 276, 'nzhour': 0, 'nzmin': 0, 'nzsec': 50, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8637706, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# CHMB
# SSNB
# ZANB
#          network: TW
#          station: SSNB
#         location:
#          channel: EV
#        starttime: 2009-10-03T17:35:36.119542Z
#          endtime: 2009-10-03T17:39:06.119542Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2009, 10, 3, 17, 39, 6, 119542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2009, 10, 3, 17, 35, 36, 119542))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2009, 'nzjday': 276, 'nzhour': 0, 'nzmin': 0, 'nzsec': 21, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8641537, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: SSNB
#         location:
#          channel: EV
#        starttime: 2009-10-03T17:35:36.119542Z
#          endtime: 2009-10-03T17:39:06.119542Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2009, 10, 3, 17, 39, 6, 119542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2009, 10, 3, 17, 35, 36, 119542))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2009, 'nzjday': 276, 'nzhour': 0, 'nzmin': 0, 'nzsec': 21, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8641537, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# FBRB
#          network: TW
#          station: SSNB
#         location:
#          channel: EV
#        starttime: 2009-10-03T17:35:36.119542Z
#          endtime: 2009-10-03T17:39:06.119542Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2009, 10, 3, 17, 39, 6, 119542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2009, 10, 3, 17, 35, 36, 119542))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2009, 'nzjday': 276, 'nzhour': 0, 'nzmin': 0, 'nzsec': 19, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8640113, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: SSNB
#         location:
#          channel: EV
#        starttime: 2009-10-03T17:35:36.119542Z
#          endtime: 2009-10-03T17:39:06.119542Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2009, 10, 3, 17, 39, 6, 119542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2009, 10, 3, 17, 35, 36, 119542))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2009, 'nzjday': 276, 'nzhour': 0, 'nzmin': 0, 'nzsec': 19, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8640113, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# SSTB
# DONB
# 2013-10-31T12:02:08.720000Z
# BCWB
# TRKB
#          network: TW
#          station: TRKB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000393, 'e': 86354.05, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 48, 'nzmsec': 658, 'nvhdr': 6, 'npts': 8280001, 'iftype': 1, 'leven': 1, 'kstnm': 'TRKB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
#          network: TW
#          station: TRKB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000393, 'e': 86354.05, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 48, 'nzmsec': 658, 'nvhdr': 6, 'npts': 8280001, 'iftype': 1, 'leven': 1, 'kstnm': 'TRKB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
# NTTB
# SJNB
#          network: TW
#          station: SJNB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000393, 'e': 86433.75, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 2, 'nzmsec': 38, 'nvhdr': 6, 'npts': 8643376, 'iftype': 1, 'leven': 1, 'kstnm': 'SJNB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
#          network: TW
#          station: SJNB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000393, 'e': 86433.75, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 2, 'nzmsec': 38, 'nvhdr': 6, 'npts': 8643376, 'iftype': 1, 'leven': 1, 'kstnm': 'SJNB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
# HGSB
#          network: TW
#          station: CHMB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000393, 'e': 86399.99, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 0, 'nzmsec': 8, 'nvhdr': 6, 'npts': 8640000, 'iftype': 1, 'leven': 1, 'kstnm': 'CHMB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
#          network: TW
#          station: HGSB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000393, 'e': 86399.99, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 0, 'nzmsec': 8, 'nvhdr': 6, 'npts': 8640000, 'iftype': 1, 'leven': 1, 'kstnm': 'CHMB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
# CHMB
#          network: TW
#          station: CHMB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000393, 'e': 86399.99, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 0, 'nzmsec': 8, 'nvhdr': 6, 'npts': 8640000, 'iftype': 1, 'leven': 1, 'kstnm': 'CHMB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
#          network: TW
#          station: CHMB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000393, 'e': 86399.99, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 0, 'nzmsec': 8, 'nvhdr': 6, 'npts': 8640000, 'iftype': 1, 'leven': 1, 'kstnm': 'CHMB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
# SSNB
#          network: TW
#          station: SSNB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000393, 'e': 86399.99, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 0, 'nzmsec': 8, 'nvhdr': 6, 'npts': 8640000, 'iftype': 1, 'leven': 1, 'kstnm': 'SSNB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
#          network: TW
#          station: SSNB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000393, 'e': 86399.99, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 0, 'nzmsec': 8, 'nvhdr': 6, 'npts': 8640000, 'iftype': 1, 'leven': 1, 'kstnm': 'SSNB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
# ZANB
#          network: TW
#          station: ZANB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718394Z
#          endtime: 2013-10-31T12:05:08.718394Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718394)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718394))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000394, 'e': 86399.99, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 0, 'nzmsec': 8, 'nvhdr': 6, 'npts': 8640000, 'iftype': 1, 'leven': 1, 'kstnm': 'ZANB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
#          network: TW
#          station: ZANB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718394Z
#          endtime: 2013-10-31T12:05:08.718394Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718394)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718394))']
#              sac: AttribDict({'delta': 0.01, 'b': 0.000394, 'e': 86399.99, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 0, 'nzmsec': 8, 'nvhdr': 6, 'npts': 8640000, 'iftype': 1, 'leven': 1, 'kstnm': 'ZANB', 'kcmpnm': 'EV', 'knetwk': 'TW', 'kevnm': ''})
# FBRB
#          network: TW
#          station: FBRB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': -0.341607, 'e': 86391.305, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 17, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8639166, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'FBRB', 'kevnm': '133040000H1A', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: FBRB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718393Z
#          endtime: 2013-10-31T12:05:08.718393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718393)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718393))']
#              sac: AttribDict({'delta': 0.01, 'b': -0.341607, 'e': 86391.305, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 17, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8639166, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'FBRB', 'kevnm': '133040000H1A', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# SSTB
#          network: TW
#          station: SSTB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718391Z
#          endtime: 2013-10-31T12:05:08.718391Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718391)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718391))']
#              sac: AttribDict({'delta': 0.01, 'b': -0.151609, 'e': 86444.016, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 4, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8644418, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSTB', 'kevnm': '133040000H1A', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: SSTB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.718391Z
#          endtime: 2013-10-31T12:05:08.718391Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 21001
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 718391)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 718391))']
#              sac: AttribDict({'delta': 0.01, 'b': -0.151609, 'e': 86444.016, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 0, 'nzsec': 4, 'nzmsec': 0, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 8644418, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSTB', 'kevnm': '133040000H1A', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# DONB
#          network: TW
#          station: DONB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.738536Z
#          endtime: 2013-10-31T12:05:08.738536Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 738536)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 738536))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.319536, 'e': 86426.37, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 3, 'nzsec': 21, 'nzmsec': 319, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1710001, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'DONB', 'kevnm': '133040003B1A', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: DONB
#         location:
#          channel: EV
#        starttime: 2013-10-31T12:01:38.738536Z
#          endtime: 2013-10-31T12:05:08.738536Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2013, 10, 31, 12, 5, 8, 738536)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2013, 10, 31, 12, 1, 38, 738536))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.319536, 'e': 86426.37, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2013, 'nzjday': 304, 'nzhour': 0, 'nzmin': 3, 'nzsec': 21, 'nzmsec': 319, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1710001, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'DONB', 'kevnm': '133040003B1A', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# 2018-02-04T13:56:41.950000Z
# BCWB
# TRKB
#          network: TW
#          station: TRKB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.958542Z
#          endtime: 2018-02-04T13:59:41.958542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 958542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 958542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 5, 'nzmsec': 689, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1717918, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'TRKB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: TRKB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.958542Z
#          endtime: 2018-02-04T13:59:41.958542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 958542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 958542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 5, 'nzmsec': 689, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1717918, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'TRKB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# NTTB
# SJNB
#          network: TW
#          station: SJNB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.947542Z
#          endtime: 2018-02-04T13:59:41.947542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 947542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 947542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 45, 'nzmsec': 228, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1728205, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SJNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: SJNB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.947542Z
#          endtime: 2018-02-04T13:59:41.947542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 947542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 947542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 45, 'nzmsec': 228, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1728205, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SJNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# HGSB
#          network: TW
#          station: HGSB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.947542Z
#          endtime: 2018-02-04T13:59:41.947542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 947542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 947542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 30, 'nzmsec': 178, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1728545, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'HGSB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: HGSB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.947542Z
#          endtime: 2018-02-04T13:59:41.947542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 947542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 947542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 30, 'nzmsec': 178, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1728545, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'HGSB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# CHMB
#          network: TW
#          station: CHMB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.947542Z
#          endtime: 2018-02-04T13:59:41.947542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 947542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 947542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 47, 'nzmsec': 428, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1727432, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'CHMB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: CHMB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.947542Z
#          endtime: 2018-02-04T13:59:41.947542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 947542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 947542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 47, 'nzmsec': 428, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1727432, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'CHMB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# SSNB
#          network: TW
#          station: SSNB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.958542Z
#          endtime: 2018-02-04T13:59:41.958542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 958542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 958542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 5, 'nzmsec': 539, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1717909, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: SSNB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.958542Z
#          endtime: 2018-02-04T13:59:41.958542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 958542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 958542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 5, 'nzmsec': 539, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1717909, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSNB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# ZANB
#          network: TW
#          station: ZANB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.937542Z
#          endtime: 2018-02-04T13:59:41.937542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 937542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 937542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 33, 'nzmsec': 668, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1727677, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'ZANB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: ZANB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.937542Z
#          endtime: 2018-02-04T13:59:41.937542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 937542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 937542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 33, 'nzmsec': 668, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1727677, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'ZANB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# FBRB
#          network: TW
#          station: FBRB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.958542Z
#          endtime: 2018-02-04T13:59:41.958542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 958542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 958542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 37, 'nzmsec': 839, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1727842, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'FBRB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: FBRB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.958542Z
#          endtime: 2018-02-04T13:59:41.958542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 958542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 958542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 37, 'nzmsec': 839, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1727842, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'FBRB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# SSTB
#          network: TW
#          station: SSTB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.938542Z
#          endtime: 2018-02-04T13:59:41.938542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 938542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 938542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 6, 'nzmsec': 369, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1728397, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSTB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
#          network: TW
#          station: SSTB
#         location:
#          channel: EV
#        starttime: 2018-02-04T13:56:11.938542Z
#          endtime: 2018-02-04T13:59:41.938542Z
#    sampling_rate: 20.0
#            delta: 0.05
#             npts: 4201
#            calib: 1.0
#          _format: SAC
#       processing: ['ObsPy 1.4.0: trim(endtime=UTCDateTime(2018, 2, 4, 13, 59, 41, 938542)::fill_value=None::nearest_sample=True::pad=False::starttime=UTCDateTime(2018, 2, 4, 13, 56, 11, 938542))']
#              sac: AttribDict({'delta': 0.05, 'b': 0.069542, 'e': 9208075.0, 'internal0': 1.0, 'cmpinc': -12255.0, 'nzyear': 2018, 'nzjday': 35, 'nzhour': 0, 'nzmin': 0, 'nzsec': 6, 'nzmsec': 369, 'nvhdr': 6, 'norid': 0, 'nevid': 0, 'npts': 1728397, 'iftype': 1, 'idep': 5, 'iztype': 11, 'ievtyp': 40, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 1, 'unused23': 0, 'kstnm': 'SSTB', 'kevnm': '113261015LS1', 'khole': '', 'kcmpnm': 'EV', 'knetwk': 'TW'})
# DONB
