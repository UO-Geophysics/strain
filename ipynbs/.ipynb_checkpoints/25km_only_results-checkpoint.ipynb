# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Need to decide whether to use normed or un-normed MCMC results
# And what time window for Tohoku

na_mcmc_results = pd.read_csv('/Users/sydneydybing/StrainProject/2024/3comp_mcmc_arrays/mcmc_results_summary_with_quality.csv')
# na_mcmc_results = pd.read_csv('/Users/sydneydybing/StrainProject/2024/3comp_norm_mcmc_arrays/mcmc_results_summary_with_quality.csv')

taiwan_mcmc_results = pd.read_csv('/Users/sydneydybing/StrainProject/2024/taiwan_strain_data/mcmc_arrays_uncal/mcmc_results_summary_with_quality.csv')
# taiwan_mcmc_results = pd.read_csv('/Users/sydneydybing/StrainProject/2024/taiwan_strain_data/mcmc_arrays_uncal_norm/mcmc_results_summary_with_quality.csv')

# %%
na_mcmc_results[na_mcmc_results['hypdist'] <= 25]
# Out:
#               eq_id  mag   sta  hypdist  xhigh        m1        m2     xinter  \
# 74  2019-07-06_M7.1  7.1  B921       23     27  0.434361  0.057745  14.373710
# 93  2019-07-04_M6.4  6.4  B921       13     20  3.333773  0.145910  10.627778
#
#        sigma  trans_time two_line_fit_qual
# 74  0.100366        14.4                 g
# 93  0.206341        10.7                 g

# %%
taiwan_mcmc_results[taiwan_mcmc_results['hypdist'] <= 25]
# Out:
#               eq_id  mag   sta  hypdist  xhigh         m1        m2  \
# 1   2009-10-03_M6.1  6.1  HGSB       15     22   3.838528  0.093399
# 6   2013-10-31_M6.3  6.3  HGSB       11     20   6.131144  0.083732
# 7   2013-10-31_M6.3  6.3  CHMB       11     20  10.009627  0.079016
# 8   2013-10-31_M6.3  6.3  SSNB       16     15   8.023050  0.254595
# 9   2013-10-31_M6.3  6.3  ZANB       21     20  16.250551  0.064077
# 13  2018-02-04_M6.1  6.1  TRKB        9     13  10.034649  0.625622
# 14  2018-02-04_M6.1  6.1  SJNB       12     13   1.651085  0.404367
#
#        xinter     sigma  trans_time two_line_fit_qual
# 1   10.887917  0.169596        10.9                 g
# 6   10.344852  0.124271        10.4                 g
# 7   10.196422  0.096045        10.2                 g
# 8   10.416833  0.112027        10.5                 b
# 9   10.177638  0.105708        10.2                 g
# 13  10.172536  0.171682        10.2                 g
# 14  10.670039  0.110281        10.7                 g
