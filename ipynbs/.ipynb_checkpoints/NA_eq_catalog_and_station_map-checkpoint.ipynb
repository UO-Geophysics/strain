# %%
import pygmt
import numpy as np
import pandas as pd
# Out:
# gmt [ERROR]: Unacceptable dmmss template DDD.X
# gmt [ERROR]: FORMAT_GEO_MAP given illegal value (DDD.X)!
# gmt [ERROR]: 1 GMT Defaults conversion errors in file /Users/sydneydybing/gmt.conf!
# gmt [ERROR]: Unacceptable dmmss template DDD.X
# pygmt-session [ERROR]: Unacceptable dmmss template DDD.X
# pygmt-session [ERROR]: FORMAT_GEO_MAP given illegal value (DDD.X)!
# pygmt-session [ERROR]: 1 GMT Defaults conversion errors in file /Users/sydneydybing/gmt.conf!
# pygmt-session [ERROR]: Unacceptable dmmss template DDD.X
# pygmt-session [ERROR]: Unacceptable dmmss template DDD.X
# pygmt-session [ERROR]: FORMAT_GEO_MAP given illegal value (DDD.X)!
# pygmt-session [ERROR]: 1 GMT Defaults conversion errors in file /Users/sydneydybing/gmt.conf!
# pygmt-session [ERROR]: Unacceptable dmmss template DDD.X
# begin [ERROR]: Unacceptable dmmss template DDD.X
# begin [ERROR]: FORMAT_GEO_MAP given illegal value (DDD.X)!
# begin [ERROR]: 1 GMT Defaults conversion errors in file /Users/sydneydybing/gmt.conf!

# %%
earthquakes = pd.read_csv('/Users/sydneydybing/StrainProject/2024/M6_catalog_2004-2024.csv', dtype = str)
bsm_mda = pd.read_csv('/Users/sydneydybing/StrainProject/2024/bsm_metadata.csv')

bsm_mda
# Out:
#     BNUM              NAME        LAT        LONG  ELEV(m) INSTALL_DATE  \
# 0   AVN2  osageavn2bok2016  36.532120  -96.081020    261.0      9/10/16
# 1   B001  golbeck01bwa2005  48.043070 -123.131410    237.0      6/29/05
# 2   B003  floequarybwa2005  48.062360 -124.140860    284.7      6/21/05
# 3   B004  hokofallsbwa2005  48.201930 -124.427010     30.0      6/15/05
# 4   B005  shoresnw1bwa2005  48.059550 -123.503280    302.7      7/19/05
# ..   ...               ...        ...         ...      ...          ...
# 84  TSM2  tstartsm2bit2021  43.396190   12.489944    630.0      11/3/21
# 85  TSM3  tstartsm3bit2021  43.382980   12.354506    341.0     11/15/21
# 86  TSM4  tstartsm4bit2022  43.308700   12.304600    270.0      5/14/22
# 87  TSM5  tstartsm5bit2022  43.479691   12.602520    379.0      5/27/22
# 88  TSM6  tstartsm6bit2022  43.472460   12.332750    402.0      6/15/22
#
#    CH0(EofN)  BSM_Depth(m) SEISMOMETER_Depth(m)  PORE_DEPTH(m) DATA_START  ->  \
# 0      230.5          96.0                  NaN            NaN   2016:254  ->
# 1      200.2         152.9                144.4           20.6   2005:180  ->
# 2      250.7         169.8                159.7           50.3   2007:303  ->
# 3      168.2         166.1                156.1            3.4   2005:166  ->
# 4      319.7         161.2                  153           44.5   2005:203  ->
# ..       ...           ...                  ...            ...        ...  ..
# 84     345.4         158.1                152.5            NaN   2021:307  ->
# 85     312.1          78.6                   73            NaN   2021:319  ->
# 86   Unknown          99.3                 95.1            NaN   2022:134  ->
# 87     342.9         116.0                  111            NaN   2022:147  ->
# 88      47.3         115.5                  110            NaN   2022:166  ->
#
#    DATA_END  GAP(m)    L_DATE  L0(cnts)  L1(cnts)  L2(cnts)  L3(cnts)  \
# 0   Present  0.0001  2016:306  56115944  55743838  53304262  53874519
# 1   Present  0.0002  2005:194  50935230  50185604  50654939  51914278
# 2   Present  0.0002  2005:186  48337769  54102554  48683869  48835069
# 3   Present  0.0002  2005:180  48391551  49872537  49840454  49541470
# 4   Present  0.0002  2005:257  50378161  50000351  48306023  49183054
# ..      ...     ...       ...       ...       ...       ...       ...
# 84  Present  0.0001  2021:314  54578308  52933014  53995653  50732399
# 85  Present  0.0001  2021:326  53675042  50931471  55603089  53766332
# 86  Present  0.0001  2022:141  51839210  53148452  50803509  50425102
# 87  Present  0.0001  2022:154  50858593  53668101  53904388  49946112
# 88  Present  0.0001  2022:170  53832784  54574177  52828625  52863660
#
#               REGION
# 0           Oklahoma
# 1   PacificNorthWest
# 2   PacificNorthWest
# 3   PacificNorthWest
# 4   PacificNorthWest
# ..               ...
# 84         TabooStar
# 85         TabooStar
# 86         TabooStar
# 87         TabooStar
# 88         TabooStar
#
# [89 rows x 20 columns]

# %%
dist_array = np.load('/Users/sydneydybing/StrainProject/2024/NA_evt-sta_dist_array_less500km_withdata.npy')

dist_array.shape

# Array order:

# 0. Earthquake identifier
# 1. Earthquake origin time
# 2. Earthquake latitude
# 3. Earthquake longitude
# 4. Earthquake magnitude
# 5. Station name
# 6. Station latitude
# 7. Station longitude
# 8. Hypocentral distance
# Out:
# (439, 9)

# %%
dist_array
# Out:
# array([['2023-04-13_M6', '2023-04-13T15:54:53.808Z', '49.215', ...,
#         '48.04307', '-123.13141', '495.399747368'],
#        ['2023-04-13_M6', '2023-04-13T15:54:53.808Z', '49.215', ...,
#         '48.06236', '-124.14086', '423.396437732'],
#        ['2023-04-13_M6', '2023-04-13T15:54:53.808Z', '49.215', ...,
#         '48.20193', '-124.42701', '398.201697957'],
#        ...,
#        ['2008-01-10_M6.3', '2008-01-10T01:37:19.000Z', '43.785', ...,
#         '42.50351', '-123.38342', '346.255216587'],
#        ['2008-01-10_M6.3', '2008-01-10T01:37:19.000Z', '43.785', ...,
#         '41.4667', '-122.4847', '468.957430617'],
#        ['2008-01-10_M6.3', '2008-01-10T01:37:19.000Z', '43.785', ...,
#         '41.8308', '-122.4205', '451.644312384']], dtype='<U32')

# %%
# All North American earthquakes

pygmt.config(COLOR_BACKGROUND = 'white')

fig = pygmt.Figure()

region=[-133,-108,28,53]

fig.coast(region=region, projection="N12c", land="wheat3", water="lightcyan2", frame="afg")

# Add plate boundaries

fig.plot(data = '/Users/sydneydybing/StrainProject/2024/PB2002_boundaries.gmt', pen = '1p,darkred', style = 'f0.25/3p', fill = 'darkred')

# Plot earthquakes and stations

pygmt.makecpt(cmap="viridis", series=[earthquakes.mag.astype(float).min(), earthquakes.mag.astype(float).max()+0.3], reverse=True)
fig.plot(x = earthquakes.longitude.astype(float), y = earthquakes.latitude.astype(float), style="c0.7c", fill=earthquakes.mag.astype(float), cmap=True, pen="black", transparency = 20)
fig.plot(x = bsm_mda.LONG, y = bsm_mda.LAT, style = "t0.35c", fill = "dimgrey", pen = "black")
fig.text(x = bsm_mda.LONG+1, y = bsm_mda.LAT, text = bsm_mda.BNUM, font = '6p,black') 
with pygmt.config(FONT='18'):
    fig.colorbar(frame="af+lEarthquake magnitude")

# Make legend

with fig.inset(position="jBL+w4c/2.3c+o0.3c/0.25c", box="+p0.5+gwhite"):
    pass
fig.plot(x=-131.25, y=30.5, fill='#22a785', pen='black', style='c0.6c')
fig.text(text=['Earthquakes'], x=-127.5, y=30.5, font='12p,black')
fig.plot(x=-131.25, y=29.15, fill='dimgrey', pen='black', style='t0.35c')
fig.text(text=['Strainmeters'], x=-127.5, y=29.25, font='12p,black')
fig.text(text=['LEGEND'], x=-128.5, y=31.8, font='14p,black')

# Add inset map

with fig.inset(position="jTR+w3c+o0.9c/0.25c"):
    fig.coast(projection="G-120/40/3c", land="black", water="white")
    rectangle = [[region[0], region[2], region[1], region[3]]]
    fig.plot(data=rectangle, style="r+s", pen="1p,red")

# Show or save 

# fig.show();

fig.savefig('/Users/sydneydybing/StrainProject/2024/figures/NA_earthquake_station_map_labels.pdf');
