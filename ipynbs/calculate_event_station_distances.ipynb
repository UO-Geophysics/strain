# %%
import numpy as np

# %%
stas_locs = np.genfromtxt('/Users/sydneydybing/StrainProject/2024/stations_with_locations.txt', dtype = str)

# %%
stas_locs
# Out:
# array([['-123.131409', '48.043072', 'B001'],
#        ['-124.140862', '48.062359', 'B003'],
#        ['-124.42701', '48.201923', 'B004'],
#        ['-123.503281', '48.059547', 'B005'],
#        ['-123.500801', '48.0588', 'B006'],
#        ['-123.504112', '48.057575', 'B007'],
#        ['-123.451172', '48.64867', 'B009'],
#        ['-123.451332', '48.650169', 'B010'],
#        ['-123.448189', '48.649544', 'B011'],
#        ['-125.541977', '48.924625', 'B012'],
#        ['-122.910797', '47.813', 'B013'],
#        ['-123.8125', '47.513302', 'B014'],
#        ['-123.557503', '46.995998', 'B017'],
#        ['-123.020302', '46.9795', 'B018'],
#        ['-123.651802', '46.652699', 'B019'],
#        ['-123.844498', '46.382702', 'B020'],
#        ['-123.931046', '45.954609', 'B022'],
#        ['-123.078697', '46.111198', 'B023'],
#        ['-123.855797', '45.637798', 'B024'],
#        ['-123.823051', '45.309353', 'B026'],
#        ['-122.962166', '44.497334', 'B027'],
# ...
